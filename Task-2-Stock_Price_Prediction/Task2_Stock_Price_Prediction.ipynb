# %% [markdown]
# # 📈 Stock Price Prediction using Machine Learning
#
# ## AI/ML Internship Task - DevelopersHub Corporation

# %% [markdown]
# ## 🎯 Objective
# To predict the next day's closing stock price using historical stock data.

# %% [markdown]
# ## 📊 Dataset
# Data is fetched using the yfinance API from Yahoo Finance.

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ## 📥 Fetching Stock Data

# %%
data = yf.download("AAPL", start="2020-01-01", end="2024-01-01")
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  72.400520  72.460784  71.156682  71.409785  135480400
# 2020-01-03  71.696632  72.455950  71.472454  71.629138  146322800
# 2020-01-06  72.267937  72.306506  70.568510  70.819208  118387200
# 2020-01-07  71.928070  72.533110  71.708710  72.277594  108872000
# 2020-01-08  73.085129  73.386446  71.631574  71.631574  132079200

# %% [markdown]
# ## 🧹 Data Preprocessing

# %%
df = data[['Open','High','Low','Volume','Close']]
df['Next_Close'] = df['Close'].shift(-1)
df.dropna(inplace=True)

df.head()
# Out:
# Price            Open       High        Low     Volume      Close Next_Close
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  71.409785  72.460784  71.156682  135480400  72.400520  71.696632
# 2020-01-03  71.629138  72.455950  71.472454  146322800  71.696632  72.267937
# 2020-01-06  70.819208  72.306506  70.568510  118387200  72.267937  71.928070
# 2020-01-07  72.277594  72.533110  71.708710  108872000  71.928070  73.085129
# 2020-01-08  71.631574  73.386446  71.631574  132079200  73.085129  74.637489

# %% [markdown]
# ## 🧠 Feature Selection

# %%
X = df[['Open','High','Low','Volume']]
y = df['Next_Close']

# %% [markdown]
# ## 🔀 Train-Test Split

# %%
split = int(len(df)*0.8)

X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

# %% [markdown]
# ## 🤖 Model Training

# %%
model = RandomForestRegressor(n_estimators=100)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ## 🔮 Prediction

# %%
predictions = model.predict(X_test)

# %% [markdown]
# ## 📏 Model Evaluation

# %%
mae = mean_absolute_error(y_test, predictions)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 7.434797840023513

# %% [markdown]
# ## 📊 Visualization (Actual vs Predicted)

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test.values, label="Actual Price")
plt.plot(predictions, label="Predicted Price")
plt.title("Stock Price Prediction")
plt.xlabel("Days")
plt.ylabel("Price")
plt.legend()
plt.show()
